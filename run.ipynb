# %%
from src.split_data import split_dataset

split_dataset(
        source_dir="PlantVillage",
        output_dir="data"
    )

# %%
# !python src/train.py --batch_size 32 --lr 0.001 --num_epochs 5
# Out:
# Epoch: 1 | train_loss: 0.8274 | train_acc: 0.7983 | val_loss: 0.4078 | val_acc: 0.8980
#
#
# Epoch: 2 | train_loss: 0.3845 | train_acc: 0.8950 | val_loss: 0.2887 | val_acc: 0.9248
#
#
# Epoch: 3 | train_loss: 0.3159 | train_acc: 0.9056 | val_loss: 0.2366 | val_acc: 0.9326
#
#
# Epoch: 4 | train_loss: 0.2775 | train_acc: 0.9174 | val_loss: 0.2106 | val_acc: 0.9385
#
#
# Epoch: 5 | train_loss: 0.2586 | train_acc: 0.9227 | val_loss: 0.1936 | val_acc: 0.9468
#
# ===== Best Model =====
# Epoch: 5
# Train Loss: 0.2586 | Train Acc: 0.92%
# val Loss: 0.1936 | val Acc: 0.95%
# [INFO] Training curves saved to: results/training_curves.png
# [INFO] Saving model to: models/efficientnet_b0_plant_disease.pth

# %%
# !python src/evaluation.py
# Out:
# Using device: cuda
#
# ===== Test Results =====
# Test Loss: 0.1356
# Test Accuracy: 0.9512
#
# ===== Classification Report =====
#                                              precision    recall  f1-score   support
#
#               Pepper__bell___Bacterial_spot       1.00      0.99      0.99       150
#                      Pepper__bell___healthy       0.97      1.00      0.99       222
#                       Potato___Early_blight       0.97      1.00      0.99       150
#                        Potato___Late_blight       0.95      0.97      0.96       150
#                            Potato___healthy       0.96      0.96      0.96        23
#                       Tomato_Bacterial_spot       0.93      0.97      0.95       320
#                         Tomato_Early_blight       0.86      0.82      0.84       153
#                          Tomato_Late_blight       0.89      0.96      0.93       287
# ...

# %%
# !python src/predict.py --image early_bright.JPG
# Out:
# ===== Prediction =====
# Class: Tomato_Early_blight
# Confidence: 99.99%

# %%
# !python src/gradcam.py --image early_bright.JPG
# Out:
# ===== Prediction =====
# Class: Tomato_Early_blight
# Confidence: 99.99%
# Grad-CAM saved to: results/gradcam_Tomato_Early_blight.png
# Figure(1000x500)
